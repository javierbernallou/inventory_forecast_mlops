# %% [markdown]
# Vamos a comprobar que el dataset se ha creado correctamente

# %%
import pandas as pd

df = pd.read_parquet("../data/processed/retail_dataset.parquet")

# %% [markdown]
# Valores nulos:

# %%
df.isnull().sum()
# Out:
# id                     0
# item_id                0
# dept_id                0
# cat_id                 0
# store_id               0
# state_id               0
# d                      0
# sales                  0
# date                   0
# wm_yr_wk               0
# weekday                0
# wday                   0
# month                  0
# year                   0
# event_name_1    21452764
# event_type_1    21452764
# event_name_2    23282164
# event_type_2    23282164
# snap_CA                0
# snap_TX                0
# snap_WI                0
# sell_price       5113150
# dtype: int64

# %% [markdown]
# Estos nulos en eventos y precio de venta son normales. De momento todo esta correcto.

# %%
df["date"].min(), df["date"].max()
# Out:
# ('2011-01-29', '2016-04-24')

# %% [markdown]
# El dataset recorre desde principios de 2011 hasta abril del 2016.

# %%
df.groupby(["store_id", "item_id"]).size().head()
# Out:
# C:\Users\tela\AppData\Local\Temp\ipykernel_31524\1488077201.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["store_id", "item_id"]).size().head()
# store_id  item_id
# CA_1      FOODS_1_001    1913
#           FOODS_1_002    1913
#           FOODS_1_003    1913
#           FOODS_1_004    1913
#           FOODS_1_005    1913
# dtype: int64

# %% [markdown]
# No se ha perdido ningún valor durante el melt. Cada fila representa las ventas de un producto específico en una sucursal específica en un día concreto.

# %%
df.duplicated().sum()
df.dtypes
# Out:
# 0
